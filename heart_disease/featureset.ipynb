# %%
import sys
reload(sys)
sys.setdefaultencoding('utf8')
import io
import numpy as np
import pandas as pd

# %%
df = open('processed_cleveland_data.txt', 'r')
data=[]
for line in df:
    data.append(line)

# %%
def remove_cruft(s):
    return s[:-4]

data = [remove_cruft(s) for s in data]

data =[line.split(',') for line in data]

# %%
data
# Out:
# [['63.0',
#   '1.0',
#   '1.0',
#   '145.0',
#   '233.0',
#   '1.0',
#   '2.0',
#   '150.0',
#   '0.0',
#   '2.3',
#   '3.0',
#   '0.0',
#   '6.'],
#  ['67.0',
#   '1.0',
#   '4.0',
#   '160.0',
#   '286.0',
#   '0.0',
#   '2.0',
#   '108.0',
#   '1.0',
#   '1.5',
#   '2.0',
#   '3.0',
#   '3.'],
#  ['67.0',
#   '1.0',
#   '4.0',
#   '120.0',
#   '229.0',
#   '0.0',
#   '2.0',
#   '129.0',
#   '1.0',
#   '2.6',
#   '2.0',
#   '2.0',
#   '7.'],
#  ['37.0',
#   '1.0',
#   '3.0',
#   '130.0',
#   '250.0',
#   '0.0',
#   '0.0',
#   '187.0',
#   '0.0',
#   '3.5',
#   '3.0',
#   '0.0',
#   '3.'],
#  ['41.0',
#   '0.0',
#   '2.0',
#   '130.0',
#   '204.0',
#   '0.0',
#   '2.0',
#   '172.0',
#   '0.0',
#   '1.4',
#   '1.0',
#   '0.0',
#   '3.'],
#  ['56.0',
#   '1.0',
#   '2.0',
#   '120.0',
#   '236.0',
#   '0.0',
#   '0.0',
#   '178.0',
#   '0.0',
#   '0.8',
#   '1.0',
#   '0.0',
#   '3.'],
#  ['62.0',
#   '0.0',
#   '4.0',
#   '140.0',
#   '268.0',
#   '0.0',
#   '2.0',
#   '160.0',
# ...

# %%
# Next step is to change each data point into an integer
